# %% [markdown]
# Create an input a path
#
#
# qiime tools import \
#   --type 'SampleData[PairedEndSequencesWithQuality]' \
#   --input-path full-sample\
#   --input-format PairedDNASequencesDirectoryFormat \
#   --output-path LE-paired-end.qza
#
#
# Example:
#
#
# qiime tools import \
#   --type 'SampleData[SequencesWithQuality]' \
#   --input-path  Samples\
#   --input-format PairedDNASequencesDirectoryFormat \
#   --output-path LakeE-paired-end.qza
#
# qiime tools import \
#   --type 'SampleData[PairedEndSequencesWithQuality]' \
#   --input-path casava-18-paired-end-demultiplexed \
#   --input-format CasavaOneEightSingleLanePerSampleDirFmt \
#   --output-path demux-paired-end.qzaqiime tools import \
#
#
#
# qiime tools import \
# --type 'SampleData[SequencesWithQuality]' \
# --input-path Samples \
# --output-path Samples/fastq.qza \
#
#
#
# --input-format FastqGzFormat
#
#
#
#
#
# CasavaOneEightSingleLanePerSampleDirFmt
# CasavaOneEightLanelessPerSampleDirFmt
# FastqGzFormat
# PairedDNASequencesDirectoryFormat
# PairedEndFastqManifestPhred33
# PairedEndFastqManifestPhred33V2
# PairedEndFastqManifestPhred64
# PairedEndFastqManifestPhred64V2
# SingleLanePerSamplePairedEndFastqDirFmt

# %% [markdown]
# conda env create -n coverm -f coverm.yml
#
# conda env coverm -f coverm.yml
#
#
#
#
#
# Sample_134807_R1_trim.fastq.gz
#
# Sample_134807_R2_trim.fastq.gz
#
# coverm contig --coupled Sample_134807_R1_trim.fastq.gz Sample_134807_R2_trim.fastq.gz --reference assembly.fna
#
#
#
#
# zcat Sample_134807_R2_trim.fastq.gz | echo $((`wc -l`/4))
